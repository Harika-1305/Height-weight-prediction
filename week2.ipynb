# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
url='/content/heights.csv'
df=pd.read_csv(url)
print(df.head())
# Out:
#    height  weight
# 0   65.78  112.99
# 1   71.52  136.49
# 2   69.40  153.03
# 3   68.22  142.34
# 4   67.79  144.30

# %%
print(df.isnull().sum())
# Out:
# height    0
# weight    0
# dtype: int64

# %%
x = df[['height']]
y = df['weight']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (160, 1)
# Shape of x_test: (40, 1)
# Shape of y_train: (160,)
# Shape of y_test: (40,)

# %%
# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 134.94
# R-squared: 0.15

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_test['height'], y=y_test, label='Actual Weight')
sns.lineplot(x=x_test['height'], y=y_pred, color='red', label='Predicted Weight (Regression Line)')
plt.title('Height vs. Weight (Test Data)')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend()
plt.grid(False)#chaged from true to false
plt.show()
